# %% [markdown]
# # Segmenting and Clustering neighbourhoods in Toronto
#
# ## Assignment for Applied Data Science Capstone

# %% [markdown]
# ## Part1 -
#
# ### Importing data

# %%
import requests 
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = requests.get(url)

#using Pandas to read html into dataframe
data = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M", header = 0)

df=data[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Cleaning the dataframe

# %%
df_cleaned = df[df.Borough != "Not assigned"]
df_cleaned
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
#checking if any "Not assigned" values are left in the Neighbourhood column
df_cleaned.loc[df_cleaned["Neighborhood"] == "Not assigned"]
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighborhood]
# Index: []

# %%
df_cleaned.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2 -
#
# ### Adding geographic information

# %%
df_geo = pd.read_csv(r"C:\Users\adrif\Documents\Learning\IBM Data Sciene\C9 - Applied Data Science Capstone\Geospatial_Coordinates.csv")
df_geo.head(20)
# Out:
#    Postal Code   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304
# 11         M1R  43.750072 -79.295849
# 12         M1S  43.794200 -79.262029
# 13         M1T  43.781638 -79.304302
# 14         M1V  43.815252 -79.284577
# 15         M1W  43.799525 -79.318389
# 16         M1X  43.836125 -79.205636
# 17         M2H  43.803762 -79.363452
# 18         M2J  43.778517 -79.346556
# 19         M2K  43.786947 -79.385975

# %%
#merge tables based on the Postal Code column
df = pd.merge(df_cleaned, df_geo, how="outer", on=["Postal Code"])

import numpy as np

df[["Latitude", "Longitude"]] = np.round(df[["Latitude", "Longitude"]], decimals=2)
df.shape
# Out:
# (103, 5)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    Latitude  Longitude
# 0     43.75     -79.33
# 1     43.73     -79.32
# 2     43.65     -79.36
# 3     43.72     -79.46
# 4     43.66     -79.39

# %% [markdown]
# ## Part 3 -
# ### Exploring Toronto neighbourhoods
#
# I want to find if there are any swimming pools in the neighbourhoods that belong to Downtown Toronto.

# %%
#keeping only the data of Downtown Toronto neighbourhoods
df_downtown = df[df.Borough == "Downtown Toronto"]
df_downtown.set_index("Postal Code", inplace = True)
df_downtown.head()
# Out:
#                       Borough                                 Neighborhood  \
# Postal Code
# M5A          Downtown Toronto                    Regent Park, Harbourfront
# M7A          Downtown Toronto  Queen's Park, Ontario Provincial Government
# M5B          Downtown Toronto                     Garden District, Ryerson
# M5C          Downtown Toronto                               St. James Town
# M5E          Downtown Toronto                                  Berczy Park
#
#              Latitude  Longitude
# Postal Code
# M5A             43.65     -79.36
# M7A             43.66     -79.39
# M5B             43.66     -79.38
# M5C             43.65     -79.38
# M5E             43.64     -79.37

# %% [markdown]
# ### Getting data from Foursquare
#
# Preparing a request to get data on all swimming pools from Foursquare that are located in the above Downtown Toronto neighbourhoods.

# %%
#preparing Foursquare query
CLIENT_ID = 'QKXLFOGEM2RLE3AHMICC2ZHUXOZDWTFT1HLK0IP4O0MTWAUT'
CLIENT_SECRET = 'OCOYFA0RMR0M4VGKAJQZDZV50GV2MAGPZAWTJZT3MIKG2BXA'
VERSION = '20180604'
LIMIT = 200
search_query = "swimming pool"
radius = 2000

#Getting json data for Parkwoods
latitude = df_downtown.loc["M5A", "Latitude"]
longitude = df_downtown.loc["M5A", "Longitude"]

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude, 
            longitude,
            search_query,
            radius, 
            LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f04ea51e5b2125c2d78c193'},
#  'response': {'venues': [{'id': '51c0b4bf498e78941e4f6a9d',
#     'name': 'Swimming Pool',
#     'location': {'address': '123 Queen St W',
#      'crossStreet': 'between Bay St & University Ave',
#      'lat': 43.652266,
#      'lng': -79.384815,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652266,
#        'lng': -79.384815}],
#      'distance': 2014,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen St W (between Bay St & University Ave)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '55adb867498e5577b1ee1860',
#     'name': 'Novotel Swimming Pool',
#     'location': {'lat': 43.646874,
#      'lng': -79.375045,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646874,
#        'lng': -79.375045}],
#      'distance': 1260,
#      'cc': 'CA',
#      'neighborhood': 'St. Lawrence',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4d1ce7da6f0f6a312377632d',
#     'name': 'Swimming Pool at The Merchandise Lofts',
#     'location': {'address': '155 Dalhousie Street',
#      'crossStreet': 'Dundas Street',
#      'lat': 43.657048,
#      'lng': -79.37688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657048,
#        'lng': -79.37688}],
#      'distance': 1569,
#      'postalCode': 'M5B 2P7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['155 Dalhousie Street (Dundas Street)',
#       'Toronto ON M5B 2P7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4f4ec92ce4b02966d3a902e1',
#     'name': 'Swimming Pool at Hilton Garden Inn',
#     'location': {'address': '200 Dundas Street East',
#      'crossStreet': 'Jarvis',
#      'lat': 43.657454962500616,
#      'lng': -79.37667439097233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657454962500616,
#        'lng': -79.37667439097233}],
#      'distance': 1578,
#      'postalCode': 'M5A 4R6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Dundas Street East (Jarvis)',
#       'Toronto ON M5A 4R6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4e19b339c65b6bfb591a79a6',
#     'name': 'Swimming Pool @ One Park Lane',
#     'location': {'lat': 43.655438,
#      'lng': -79.38934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655438,
#        'lng': -79.38934}],
#      'distance': 2439,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '55eca10a498e895904a2bda6',
#     'name': 'Pool',
#     'location': {'address': '47 Lower River St.',
#      'lat': 43.656483,
#      'lng': -79.355144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656483,
#        'lng': -79.355144}],
#      'distance': 820,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['47 Lower River St.', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4bf46261cad2c9289bdc9b99',
#     'name': 'Deck 27 Pool & Fitness Facility',
#     'location': {'address': '33 Gerrard St W',
#      'crossStreet': 'in Delta Chelsea on 27th Floor',
#      'lat': 43.65816982438936,
#      'lng': -79.38306222018876,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65816982438936,
#        'lng': -79.38306222018876}],
#      'distance': 2068,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 Gerrard St W (in Delta Chelsea on 27th Floor)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '515e0d16e4b0e99f5f4764a8',
#     'name': 'Pool',
#     'location': {'address': 'Intercontinental',
#      'lat': 43.65097492328021,
#      'lng': -79.38405339932878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65097492328021,
#        'lng': -79.38405339932878}],
#      'distance': 1940,
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['Intercontinental', 'Ontario', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4e0e2b59c65ba20da21dbf96',
#     'name': '33 Mill St. Rooftop Pool',
#     'location': {'lat': 43.65028316599507,
#      'lng': -79.36082568182935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65028316599507,
#        'lng': -79.36082568182935}],
#      'distance': 73,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4fe8ce26e4b08e1d007d1088',
#     'name': 'doubletree pool & spa (Doubletree Pool & Spa)',
#     'location': {'address': '108 Chestnut Street',
#      'crossStreet': 'Dundas',
#      'lat': 43.654579852320154,
#      'lng': -79.38611805438995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654579852320154,
#        'lng': -79.38611805438995}],
#      'distance': 2164,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Chestnut Street (Dundas)',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4ffdea87e4b00889b03747ac',
#     'name': 'Swmming Pool',
#     'location': {'address': 'Ramada',
#      'lat': 43.660974,
#      'lng': -79.376851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.660974,
#        'lng': -79.376851}],
#      'distance': 1825,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Ramada', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '575dc110498e832d675deeeb',
#     'name': 'ST Regis Pool and Spa',
#     'location': {'lat': 43.649868,
#      'lng': -79.380295,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649868,
#        'lng': -79.380295}],
#      'distance': 1634,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c27922ea852c928f774e86c',
#     'name': 'Pinnacle Centre Fitness Centre & Pool',
#     'location': {'address': 'Pinnacle Centre',
#      'crossStreet': 'Yonge & Harbour St.',
#      'lat': 43.64308539252521,
#      'lng': -79.37718577191337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64308539252521,
#        'lng': -79.37718577191337}],
#      'distance': 1583,
#      'postalCode': 'M5E 2A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Pinnacle Centre (Yonge & Harbour St.)',
#       'Toronto ON M5E 2A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '50477f32e4b0b8500a0c0fdb',
#     'name': 'PAN AM GAMES OLYMPIC POOL',
#     'location': {'lat': 43.65343453806005,
#      'lng': -79.35695382982054,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65343453806005,
#        'lng': -79.35695382982054}],
#      'distance': 454,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '5133f6d0e4b08f94a76512ab',
#     'name': 'The Pool at Shangri-La',
#     'location': {'address': '188 University Ave',
#      'crossStreet': 'Adelaide St. W',
#      'lat': 43.64925135414941,
#      'lng': -79.38559840783742,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64925135414941,
#        'lng': -79.38559840783742}],
#      'distance': 2063,
#      'postalCode': 'M5H 0A3',
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['188 University Ave (Adelaide St. W)',
#       'Toronto ON M5H 0A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c545ac11b46c9b65e5c73ce',
#     'name': 'Riverdale Pool',
#     'location': {'lat': 43.67237958712375,
#      'lng': -79.3566898340289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67237958712375,
#        'lng': -79.3566898340289}],
#      'distance': 2505,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '51ec642e498e2a0440626dae',
#     'name': 'Hilton Garden Inn Fitness Center/Pool',
#     'location': {'address': '200 Dundas St E',
#      'lat': 43.65749150783651,
#      'lng': -79.37439788672286,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65749150783651,
#        'lng': -79.37439788672286}],
#      'distance': 1428,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Dundas St E', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4b8f0ba8f964a520494633e3',
#     'name': 'Indie Pool',
#     'location': {'address': '118 Berkeley St',
#      'crossStreet': 'Queen & Parliament',
#      'lat': 43.65445820502333,
#      'lng': -79.36564768242441,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65445820502333,
#        'lng': -79.36564768242441}],
#      'distance': 673,
#      'postalCode': 'M5A 2W9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['118 Berkeley St (Queen & Parliament)',
#       'Toronto ON M5A 2W9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c45f36ff9652d7fb7aa132b',
#     'name': 'Rooftop pool',
#     'location': {'address': '55 lombard',
#      'lat': 43.651853,
#      'lng': -79.374726,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651853,
#        'lng': -79.374726}],
#      'distance': 1203,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['55 lombard', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4cc8c0bbd338236a7cc49e7c',
#     'name': 'St Lawrence Community Centre Pool',
#     'location': {'address': '230 The Esplanade',
#      'crossStreet': 'Sherbourne',
#      'lat': 43.64955698056156,
#      'lng': -79.36506251486433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64955698056156,
#        'lng': -79.36506251486433}],
#      'distance': 410,
#      'postalCode': 'M5A 4J6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['230 The Esplanade (Sherbourne)',
#       'Toronto ON M5A 4J6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c202a2cb4e62d7f4bcfe093',
#     'name': 'Waterclub Gym & Pool',
#     'location': {'address': '8 York Street',
#      'crossStreet': 'Queens Quay',
#      'lat': 43.64002310860782,
#      'lng': -79.38177707646237,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64002310860782,
#        'lng': -79.38177707646237}],
#      'distance': 2076,
#      'postalCode': 'M5J 2Y2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['8 York Street (Queens Quay)',
#       'Toronto ON M5J 2Y2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4fad8a7be4b08541e94ca42d',
#     'name': 'Market Square Rooftop Pool',
#     'location': {'address': '80 Front Street',
#      'lat': 43.649196338393445,
#      'lng': -79.37261581420898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649196338393445,
#        'lng': -79.37261581420898}],
#      'distance': 1020,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['80 Front Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4ceec9bb13aea143b6ab6f9f',
#     'name': "Noel's Pool Table",
#     'location': {'lat': 43.646525,
#      'lng': -79.376683,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646525,
#        'lng': -79.376683}],
#      'distance': 1398,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e3931735',
#       'name': 'Pool Hall',
#       'pluralName': 'Pool Halls',
#       'shortName': 'Billiards',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/billiards_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '50046e8de4b0a74a53b5530e',
#     'name': 'Turtle Pool-Hazelburn Rooftop Deck',
#     'location': {'lat': 43.65619520838487,
#      'lng': -79.37517322416176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65619520838487,
#        'lng': -79.37517322416176}],
#      'distance': 1403,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '528153fc498e9d7f1c5e13b8',
#     'name': 'IndiePool',
#     'location': {'lat': 43.65439678566608,
#      'lng': -79.36557727938903,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65439678566608,
#        'lng': -79.36557727938903}],
#      'distance': 664,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4e53f419ae606f5737a59bbb',
#     'name': 'Pool At 53 McCaul',
#     'location': {'address': '53 McCaul',
#      'lat': 43.65202148538496,
#      'lng': -79.38975517371951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65202148538496,
#        'lng': -79.38975517371951}],
#      'distance': 2407,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['53 McCaul', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '505a1373e4b0cd60ff39b3c6',
#     'name': 'Number One York Quay Pool & Hottub',
#     'location': {'lat': 43.640159,
#      'lng': -79.378104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.640159,
#        'lng': -79.378104}],
#      'distance': 1823,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4cd8877c7d454688491ceced',
#     'name': 'The Pool in Allan Gardens',
#     'location': {'address': '296 Jarvis St',
#      'lat': 43.661829,
#      'lng': -79.375374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661829,
#        'lng': -79.375374}],
#      'distance': 1807,
#      'postalCode': 'M5A 2P2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['296 Jarvis St', 'Toronto ON M5A 2P2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d165941735',
#       'name': 'Scenic Lookout',
#       'pluralName': 'Scenic Lookouts',
#       'shortName': 'Scenic Lookout',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4dfcfc5345ddebdfeaac8196',
#     'name': 'Rooftop Pool',
#     'location': {'address': '65 Bremner Blvd',
#      'lat': 43.642949957623,
#      'lng': -79.38031998051476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642949957623,
#        'lng': -79.38031998051476}],
#      'distance': 1815,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['65 Bremner Blvd', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '51bc9841498e60d2c95153d0',
#     'name': 'Cabana Pool Bar',
#     'location': {'address': '11 Polson Pier',
#      'lat': 43.63998937832797,
#      'lng': -79.35433952248813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63998937832797,
#        'lng': -79.35433952248813}],
#      'distance': 1204,
#      'postalCode': 'M5A 1A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['11 Polson Pier', 'Toronto ON M5A 1A4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '503b9cec64a43364f9a2bc7a',
#     'name': 'Westin Pool Harbour Castle',
#     'location': {'address': '1 Harbour Square',
#      'crossStreet': 'at Bay Street',
#      'lat': 43.64086279075837,
#      'lng': -79.37604093865056,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64086279075837,
#        'lng': -79.37604093865056}],
#      'distance': 1644,
#      'postalCode': 'M5J 1A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Harbour Square (at Bay Street)',
#       'Toronto ON M5J 1A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4fad41d5e4b0cf5ea1134dca',
#     'name': 'Douglas Poole Antiques & Selections',
#     'location': {'address': '358 Queen St East',
#      'crossStreet': 'Parliment',
#      'lat': 43.65574187586371,
#      'lng': -79.36430691082403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65574187586371,
#        'lng': -79.36430691082403}],
#      'distance': 727,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['358 Queen St East (Parliment)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116951735',
#       'name': 'Antique Shop',
#       'pluralName': 'Antique Shops',
#       'shortName': 'Antiques',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c239662e843a59371cc49f8',
#     'name': 'Maple Leaf Indoor Pool',
#     'location': {'address': 'Maple Leaf Square',
#      'crossStreet': 'York Street',
#      'lat': 43.64032699264098,
#      'lng': -79.38081484586074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64032699264098,
#        'lng': -79.38081484586074}],
#      'distance': 1992,
#      'postalCode': 'M5J 0A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Maple Leaf Square (York Street)',
#       'Toronto ON M5J 0A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '535f83b1498edafe08fc502d',
#     'name': 'hilton pool',
#     'location': {'lat': 43.65019318872886,
#      'lng': -79.38584032854251,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65019318872886,
#        'lng': -79.38584032854251}],
#      'distance': 2081,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c2396fc13c00f47b64c89de',
#     'name': 'Maple Leaf Outdoor Pool',
#     'location': {'address': 'Maple Leaf Square',
#      'crossStreet': 'York St',
#      'lat': 43.642524,
#      'lng': -79.381286,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642524,
#        'lng': -79.381286}],
#      'distance': 1905,
#      'postalCode': 'M5J 0A6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Maple Leaf Square (York St)',
#       'Toronto ON M5J 0A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4e31c4627d8beafe2a6781c2',
#     'name': 'Sheraton Pool Lounge',
#     'location': {'address': 'Sheraton Centre',
#      'crossStreet': '123 Queen St W',
#      'lat': 43.65108286192474,
#      'lng': -79.38386156958333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65108286192474,
#        'lng': -79.38386156958333}],
#      'distance': 1925,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Sheraton Centre (123 Queen St W)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4e187e6152b123a586d715f2',
#     'name': 'Jimmie Simpson Wading Pool',
#     'location': {'lat': 43.662744745246115,
#      'lng': -79.34477074220345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.662744745246115,
#        'lng': -79.34477074220345}],
#      'distance': 1875,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '51ed43a9498ecc3ee936da44',
#     'name': 'RiverCity',
#     'location': {'address': '51 Trolley Crescent',
#      'lat': 43.65627783610465,
#      'lng': -79.35529024300884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65627783610465,
#        'lng': -79.35529024300884}],
#      'distance': 795,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['51 Trolley Crescent', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '54d3cc72498e3a30ccfdb2d5',
#     'name': 'Delta Toronto Pool',
#     'location': {'lat': 43.64310382524819,
#      'lng': -79.38389944689007,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64310382524819,
#        'lng': -79.38389944689007}],
#      'distance': 2072,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4da5005a1e72a3244fa612a2',
#     'name': 'Harrison Pool',
#     'location': {'address': '15 Stephanie St',
#      'crossStreet': 'McCaul St',
#      'lat': 43.651291,
#      'lng': -79.390938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651291,
#        'lng': -79.390938}],
#      'distance': 2496,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Stephanie St (McCaul St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4c79825393ef236ae3e3af0f',
#     'name': 'Aqua Spa + Pool @ One City Hall',
#     'location': {'address': '111 Elizabeth Street',
#      'crossStreet': 'Dundas',
#      'lat': 43.65486703655056,
#      'lng': -79.38509593154721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65486703655056,
#        'lng': -79.38509593154721}],
#      'distance': 2092,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Elizabeth Street (Dundas)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d105941735',
#       'name': 'Gym Pool',
#       'pluralName': 'Gym Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False},
#    {'id': '4b818bb5f964a520fbad30e3',
#     'name': "L'Esprit - Poolside",
#     'location': {'address': '15 Maitland Place',
#      'crossStreet': 'Jarvis Street',
#      'lat': 43.66527335259677,
#      'lng': -79.37620149855756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66527335259677,
#        'lng': -79.37620149855756}],
#      'distance': 2143,
#      'postalCode': 'M4Y 2X3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Maitland Place (Jarvis Street)',
#       'Toronto ON M4Y 2X3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d108951735',
#       'name': "Women's Store",
#       'pluralName': "Women's Stores",
#       'shortName': "Women's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1594157865',
#     'hasPerk': False}]}}

# %%
#function to retrieve data for each downtown neighbourhood
def getSwimmingpools(names, latitudes, longitudes):
    
    pools_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
       
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            search_query,
            radius, 
            LIMIT)
        
        
        results = requests.get(url).json()["response"]["venues"]
        
        
    return(results)

# %%
downtown_swimming = getSwimmingpools(names = df_downtown["Neighborhood"], latitudes = df_downtown["Latitude"], longitudes = df_downtown["Longitude"])

print(downtown_swimming)
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# [{'id': '51c0b4bf498e78941e4f6a9d', 'name': 'Swimming Pool', 'location': {'address': '123 Queen St W', 'crossStreet': 'between Bay St & University Ave', 'lat': 43.652266, 'lng': -79.384815, 'labeledLatLngs': [{'label': 'display', 'lat': 43.652266, 'lng': -79.384815}], 'distance': 2011, 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['123 Queen St W (between Bay St & University Ave)', 'Toronto ON', 'Canada']}, 'categories': [{'id': '4bf58dd8d48988d132951735', 'name': 'Hotel Pool', 'pluralName': 'Hotel Pools', 'shortName': 'Pool', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1594206182', 'hasPerk': False}, {'id': '58bf0a7952e32d68b9bddb5c', 'name': 'swimming pool @ Holiday inn', 'location': {'lat': 43.661551, 'lng': -79.380566, 'labeledLatLngs': [{'label': 'display', 'lat': 43.661551, 'lng': -79.380566}], 'distance': 941, 'cc': 'CA', 'country': 'Canada', 'formattedAddress': ['Canada']}, 'categories': [{'id': '4bf58dd8d48988d15e941735', 'name': 'Pool', 'pluralName': 'Pools', 'shortName': 'Pool', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1594206182', 'hasPerk': False}, {'id': '50faac1880558056ffde6d80', 'name': 'Residences at College Park Swimming Pool', 'location': {'address': '763 Bay St.', 'crossStreet': 'at College St.', 'lat': 43.66002497782762, 'lng': -79.38501834869385, 'labeledLatLngs': [{'label': 'display', 'lat': 43.66002497782762, 'lng': -79.38501834869385}], 'distance': 1181, 'postalCode': 'M5G 2R3', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['763 Bay St. (at College St.)', 'Toronto ON M5G 2R3', 'Canada']}, 'categories': [{'id': '4bf58dd8d48988d105941735', 'name': 'Gym Pool', 'pluralName': 'Gym Pools', 'shortName': 'Pool', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1594206182', 'hasPerk': False}, {'id': '4f4ec92ce4b02966d3a902e1', 'name': 'Swimming Pool at Hilton Garden Inn', 'location': {'address': '200 Dundas Street East', 'crossStreet': 'Jarvis', 'lat': 43.657454962500616, 'lng': -79.37667439097233, 'labeledLatLngs': [{'label': 'display', 'lat': 43.657454962500616, 'lng': -79.37667439097233}], 'distance': 1421, 'postalCode': 'M5A 4R6', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['200 Dundas Street East (Jarvis)', 'Toronto ON M5A 4R6', 'Canada']}, 'categories': [{'id': '4bf58dd8d48988d132951735', 'name': 'Hotel Pool', 'pluralName': 'Hotel Pools', 'shortName': 'Pool', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1594206182', 'hasPerk': False}, {'id': '4d1ce7da6f0f6a312377632d', 'name': 'Swimming Pool at The Merchandise Lofts', 'location': {'address': '155 Dalhousie Street', 'crossStreet': 'Dundas Street', 'lat': 43.657048, 'lng': -79.37688, 'labeledLatLngs': [{'label': 'display', 'lat': 43.657048, 'lng': -79.37688}], 'distance': 1463, 'postalCode': 'M5B 2P7', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['155 Dalhousie Street (Dundas Street)', 'Toronto ON M5B 2P7', 'Canada']}, 'categories': [{'id': '4bf58dd8d48988d105941735', 'name': 'Gym Pool', 'pluralName': 'Gym Pools', 'shortName': 'Pool', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1594206182', 'hasPerk': False}, {'id': '4e19b339c65b6bfb591a79a6', 'name': 'Swimming Pool @ One Park Lane', 'location': {'lat': 43.655438, 'lng': -79.38934, 'labeledLatLngs': [{'label': 'display', 'lat': 43.655438, 'lng': -79.38934}], 'distance': 1787, 'cc': 'CA', 'country': 'Canada', 'formattedAddress': ['Canada']}, 'categories': [{'id': '4d954b06a243a5684965b4 ...

# %% [markdown]
# ### Creating & cleaning pandas dataframe

# %%
df_dt_swimming = pd.json_normalize(downtown_swimming)

df_dt_swimming = df_dt_swimming[["name", "categories", "location.address", "location.lat", "location.lng", "location.postalCode"]]
df_dt_swimming.rename(columns = {"name":"Name", "location.address": "Address", "location.lat": "Latitude", "location.lng": "Longitude", "location.postalCode": "Post Code"}, inplace = True)

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

df_dt_swimming['categories'] = df_dt_swimming.apply(get_category_type, axis=1)
df_dt_swimming.rename(columns = {"categories":"Categories"}, inplace = True)

print(df_dt_swimming.shape)
df_dt_swimming.head()
# Out:
# (50, 6)
#                                        Name  Categories  \
# 0                             Swimming Pool  Hotel Pool
# 1               swimming pool @ Holiday inn        Pool
# 2  Residences at College Park Swimming Pool    Gym Pool
# 3        Swimming Pool at Hilton Garden Inn  Hotel Pool
# 4    Swimming Pool at The Merchandise Lofts    Gym Pool
#
#                   Address   Latitude  Longitude Post Code
# 0          123 Queen St W  43.652266 -79.384815       NaN
# 1                     NaN  43.661551 -79.380566       NaN
# 2             763 Bay St.  43.660025 -79.385018   M5G 2R3
# 3  200 Dundas Street East  43.657455 -79.376674   M5A 4R6
# 4    155 Dalhousie Street  43.657048 -79.376880   M5B 2P7

# %% [markdown]
# ### Visualisation
#
# Creating a map of all swimming pools located in Downtown Toronto.

# %%
import folium

# create map
map_dt_swimming = folium.Map(location=[43.65,-79.37], zoom_start=13)

# add markers to the map
markers_colors = []
for lat, lng, label in zip(df_dt_swimming['Latitude'], df_dt_swimming['Longitude'], df_dt_swimming['Name']):
    labels = folium.Popup(str(label), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=labels,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7).add_to(map_dt_swimming)
       
map_dt_swimming
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I need to save the map as an image, because GitHub doesn't display the folium map, however, the interactive map works well when you open it in Jupyter notebooks or another text editor.

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread(r'C:\Users\adrif\Documents\map_dt_swimming.PNG')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
